# %%
import icartt
import pandas as pd
import numpy as np
import datetime
from math import pi
import os

# Initialize a translation table to remove non-numeric characters
translation_table = str.maketrans('','','abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-/:;<=>?@[\\]^_`{|}~\t')

#import csv files with information
file_info_file = "C:/Users/cphal/OneDrive/Desktop/Aerosols/Module A/Metadata/module_a_bins.csv"
binlocations = pd.read_csv(file_info_file)

#function purpose: get new file name
def get_new_name(filename, binlocations):
    #find associated row by looping through files
    campaign = ''
    instrument = ''
    i = 0
    campaign_found = False
    instrument_found = False
    while (i < len(binlocations) or (not campaign_found and not instrument_found)):
        if (not campaign_found and isinstance(binlocations.iloc[i]['Campaign'],str)):
            if(binlocations.iloc[i]['Campaign'] in filename):
                campaign = binlocations.iloc[i]['Campaign']
                campaign_found = True
        if (not instrument_found and isinstance(binlocations.iloc[i]['Filename/Instrument'],str)):
            if(binlocations.iloc[i]['Filename/Instrument'] in filename):
                instrument = binlocations.iloc[i]['Filename nickname']
                instrument_found = True
        i += 1

    if(not campaign_found or not instrument_found):
        print('FATAL ERROR: campaign/instrument not found for ' + filename)
        exit()
    
    #find new filename and get its index
    new_file_name = campaign + '_' + instrument + '_'

    return new_file_name


#function purpose: get bin starting string
def get_bin_loc(new_file_name,binlocations):
    ind_list = binlocations.index[binlocations['New File Name'] == new_file_name].tolist()

    if(len(ind_list) != 1):
        print('FATAL ERROR: Number of matches found not equal to 1 for ' + filename)
        exit()

    bin_loc = binlocations.iloc[ind_list[0]]['Bin Location']

    return bin_loc


#get units from file
def get_unit_info(varnames,ict):
    varDf = pd.DataFrame(columns=['var_name','unit','descr','descr_long'])

    #split rows of data and put into df
    for x in varnames:
        var = str(ict.variables[x])
        varAr = var.split(',')
        while len(varAr) < 4:
            varAr.append('')
        varDf.loc[len(varDf)] = varAr
    
    return varDf

# %%
filebeginning = 'C:/Users/cphal/OneDrive/Desktop/Aerosols/Module A/Success/'
filename = filebeginning + 'DC3-LARGE-LAS-PSL_DC8_20120607_R2.ict'

# %%
##for one file (filename) at top
#get new file name and bin locations
new_file_name = get_new_name(filename, binlocations)
#bin_loc = get_bin_loc(new_file_name,binlocations)

#load in ict file to python
ict = icartt.Dataset(filename)
df = ict.data[:]

#get variable names and create dataframe based on this
varnames = [x for x in ict.variables]
df = pd.DataFrame(df, columns = varnames)
varDf = get_unit_info(varnames,ict)

varDf
# Out:
# c:\Users\cphal\AppData\Local\Programs\Python\Python311\Lib\site-packages\icartt\dataset.py:392: UserWarning: Variable short name IntegN_Dopt90to7500nm_PSL_LAS_LARGE does not comply with ICARTT standard v2
#   warnings.warn(
# c:\Users\cphal\AppData\Local\Programs\Python\Python311\Lib\site-packages\icartt\dataset.py:392: UserWarning: Variable short name IntegS_Dopt90to7500nm_PSL_LAS_LARGE does not comply with ICARTT standard v2
#   warnings.warn(
# c:\Users\cphal\AppData\Local\Programs\Python\Python311\Lib\site-packages\icartt\dataset.py:392: UserWarning: Variable short name IntegV_Dopt90to7500nm_PSL_LAS_LARGE does not comply with ICARTT standard v2
#   warnings.warn(
#                                var_name                 unit
# 0                             Start_UTC  Secs after midnight  \
# 1                                 stdPT             unitless
# 2   IntegN_Dopt90to7500nm_PSL_LAS_LARGE                #/cm3
# 3   IntegS_Dopt90to7500nm_PSL_LAS_LARGE              um2/cm3
# 4   IntegV_Dopt90to7500nm_PSL_LAS_LARGE              um3/cm3
# 5          dNdlogDp_PSL_100nm_LAS_LARGE                #/cm3
# 6          dNdlogDp_PSL_112nm_LAS_LARGE                #/cm3
# 7          dNdlogDp_PSL_126nm_LAS_LARGE                #/cm3
# 8          dNdlogDp_PSL_141nm_LAS_LARGE                #/cm3
# 9          dNdlogDp_PSL_158nm_LAS_LARGE                #/cm3
# 10         dNdlogDp_PSL_178nm_LAS_LARGE                #/cm3
# 11         dNdlogDp_PSL_200nm_LAS_LARGE                #/cm3
# 12         dNdlogDp_PSL_224nm_LAS_LARGE                #/cm3
# 13         dNdlogDp_PSL_251nm_LAS_LARGE                #/cm3
# 14         dNdlogDp_PSL_282nm_LAS_LARGE                #/cm3
# 15         dNdlogDp_PSL_316nm_LAS_LARGE                #/cm3
# 16         dNdlogDp_PSL_355nm_LAS_LARGE                #/cm3
# 17         dNdlogDp_PSL_398nm_LAS_LARGE                #/cm3
# 18         dNdlogDp_PSL_447nm_LAS_LARGE                #/cm3
# 19         dNdlogDp_PSL_501nm_LAS_LARGE                #/cm3
# 20         dNdlogDp_PSL_562nm_LAS_LARGE                #/cm3
# 21         dNdlogDp_PSL_631nm_LAS_LARGE                #/cm3
# 22         dNdlogDp_PSL_708nm_LAS_LARGE                #/cm3
# 23         dNdlogDp_PSL_794nm_LAS_LARGE                #/cm3
# 24         dNdlogDp_PSL_891nm_LAS_LARGE                #/cm3
# 25        dNdlogDp_PSL_1000nm_LAS_LARGE                #/cm3
# 26        dNdlogDp_PSL_1259nm_LAS_LARGE                #/cm3
# 27        dNdlogDp_PSL_1585nm_LAS_LARGE                #/cm3
# 28        dNdlogDp_PSL_1995nm_LAS_LARGE                #/cm3
# 29        dNdlogDp_PSL_2512nm_LAS_LARGE                #/cm3
# 30        dNdlogDp_PSL_3162nm_LAS_LARGE                #/cm3
# 31        dNdlogDp_PSL_3981nm_LAS_LARGE                #/cm3
# 32        dNdlogDp_PSL_5012nm_LAS_LARGE                #/cm3
# 33        dNdlogDp_PSL_6310nm_LAS_LARGE                #/cm3
#
#                                                 descr descr_long
# 0                                 Time of acquisition
# 1   Conversion factor to convert between ambient a...
# 2   Number_concentration_of_particles_in_air_integ...
# 3   Surface_area_concentration_of_particles_in_air...
# 4   Volume_concentration_of_particles_in_air_integ...
# 5   number_size_distribution_of_particles_in_air_p...
# 6   number_size_distribution_of_particles_in_air_p...
# 7   number_size_distribution_of_particles_in_air_p...
# 8   number_size_distribution_of_particles_in_air_p...
# 9   number_size_distribution_of_particles_in_air_p...
# 10  number_size_distribution_of_particles_in_air_p...
# 11  number_size_distribution_of_particles_in_air_p...
# 12  number_size_distribution_of_particles_in_air_p...
# 13  number_size_distribution_of_particles_in_air_p...
# 14  number_size_distribution_of_particles_in_air_p...
# 15  number_size_distribution_of_particles_in_air_p...
# 16  number_size_distribution_of_particles_in_air_p...
# 17  number_size_distribution_of_particles_in_air_p...
# 18  number_size_distribution_of_particles_in_air_p...
# 19  number_size_distribution_of_particles_in_air_p...
# 20  number_size_distribution_of_particles_in_air_p...
# 21  number_size_distribution_of_particles_in_air_p...
# 22  number_size_distribution_of_particles_in_air_p...
# 23  number_size_distribution_of_particles_in_air_p...
# 24  number_size_distribution_of_particles_in_air_p...
# 25  number_size_distribution_of_particles_in_air_p...
# 26  number_size_distribution_of_particles_in_air_p...
# 27  number_size_distribution_of_particles_in_air_p...
# 28  number_size_distribution_of_particles_in_air_p...
# 29  number_size_distribution_of_particles_in_air_p...
# 30  number_size_distribution_of_particles_in_air_p...
# 31  number_size_distribution_of_particles_in_air_p...
# 32  number_size_distribution_of_particles_in_air_p...
# 33  number_size_distribution_of_particles_in_air_p...

# %%
#get diameters
row = 'var_name'
start_column = 5
end_column = len(varDf)
diam_list = varDf[row][start_column:end_column]

diams = [x.translate(translation_table) for x in diam_list]
diams = [float(x) for x in diams]

#append to diameter txt file
diameter_file = "C:/Users/cphal/OneDrive/Desktop/Aerosols/Module A/NASA diameters.csv"
# Append-adds at last
file1 = open(diameter_file, "a")  # append mode
file1.write(new_file_name + "," + row + "," + str(start_column) +","+ str(end_column) + "," + str(diams) + "\n")
file1.close()
